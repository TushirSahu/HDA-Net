# %%
import os
import PIL
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.models import load_model
from keras import backend as K

# %%
ddr_train=os.listdir('ddr\\train\\2')
image=PIL.Image.open('ddr\\train\\0\\007-0004-000.jpg')
image.size
plt.imshow(image)

# %%
new_img=lambda i,filename:np.array(PIL.Image.open(f'ddr\\train\\{i}\\{filename}').resize((512,512)))

# %%
h=3
w=3

for i in range(5):
  _,axes_plot=plt.subplots(h,w,figsize=(2*h,2*w))
  for axes in axes_plot:
   for ax in axes:
      ax.axis('off')
      img=np.random.choice(os.listdir(f'ddr\\train\\{i}'))
      ax.imshow(new_img(i,img))
      ax.set_title(f'DR_Grading_{i}')

# %%
model_name=load_model('new/mobilenet1.029.h5')
image=PIL.Image.open('ddr\\train\\0\\007-0004-000.jpg')
image.size
# Out:
# (512, 512)
